# %%
import pandas as pd
import numpy as np

# %%
jan_2019 = "data/jan_2019.csv"
feb_2019 = "data/feb_2019.csv"
mar_2019 = "data/mar_2019.csv"
apr_2019 = "data/apr_2019.csv"
may_2019 = "data/may_2019.csv"
june_2019 = "data/june_2019.csv"
july_2019 = "data/july_2019.csv"
aug_2019 = "data/aug_2019.csv"
sept_2019 = "data/sept_2019.csv"
oct_2019 = "data/oct_2019.csv"
nov_2019 = "data/nov_2019.csv"
dec_2019 = "data/dec_2019.csv"

# %%
jan_2019_df = pd.read_csv(jan_2019)
feb_2019_df = pd.read_csv(feb_2019)
mar_2019_df = pd.read_csv(mar_2019)
apr_2019_df = pd.read_csv(apr_2019)
may_2019_df = pd.read_csv(may_2019)
june_2019_df = pd.read_csv(june_2019)
july_2019_df = pd.read_csv(july_2019)
aug_2019_df = pd.read_csv(aug_2019)
sept_2019_df = pd.read_csv(sept_2019)
oct_2019_df = pd.read_csv(oct_2019)
nov_2019_df = pd.read_csv(nov_2019)
dec_2019_df = pd.read_csv(dec_2019)

jan_2019_df.head()
# Out:
#    tripduration starttime stoptime  start station id start station name  \
# 0           201   09:09.7  12:30.9              3183     Exchange Place
# 1           505   18:00.1  26:25.9              3183     Exchange Place
# 2           756   36:33.3  49:10.3              3183     Exchange Place
# 3          1575   43:38.6  09:54.5              3183     Exchange Place
# 4          1566   43:39.6  09:46.5              3183     Exchange Place
#
#    start station latitude  start station longitude  end station id  \
# 0               40.716247               -74.033459            3214
# 1               40.716247               -74.033459            3638
# 2               40.716247               -74.033459            3192
# 3               40.716247               -74.033459            3638
# 4               40.716247               -74.033459            3638
#
#      end station name  end station latitude  end station longitude  bikeid  \
# ...

# %%
citibike_2019_df = pd.concat([jan_2019_df, feb_2019_df, mar_2019_df, apr_2019_df, may_2019_df, june_2019_df, july_2019_df, aug_2019_df, sept_2019_df, oct_2019_df, nov_2019_df, dec_2019_df ])

citibike_2019_df.head()
# Out:
#    tripduration starttime stoptime  start station id start station name  \
# 0           201   09:09.7  12:30.9              3183     Exchange Place
# 1           505   18:00.1  26:25.9              3183     Exchange Place
# 2           756   36:33.3  49:10.3              3183     Exchange Place
# 3          1575   43:38.6  09:54.5              3183     Exchange Place
# 4          1566   43:39.6  09:46.5              3183     Exchange Place
#
#    start station latitude  start station longitude  end station id  \
# 0               40.716247               -74.033459            3214
# 1               40.716247               -74.033459            3638
# 2               40.716247               -74.033459            3192
# 3               40.716247               -74.033459            3638
# 4               40.716247               -74.033459            3638
#
#      end station name  end station latitude  end station longitude  bikeid  \
# ...

# %%
citibike_2019_df['Dates'] = pd.to_datetime(citibike_2019_df['starttime']).dt.date
citibike_2019_df['Time'] = pd.to_datetime(citibike_2019_df['starttime']).dt.time
citibike_2019_df.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    1860         try:
# -> 1861             values, tz_parsed = conversion.datetime_to_datetime64(data)
#    1862             # If tzaware, these values represent unix timestamps, so we
#
# pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-693758d6d401> in <module>
# ----> 1 citibike_2019_df['Dates'] = pd.to_datetime(citibike_2019_df['starttime']).dt.date
# ...
